# %% [markdown]
# <a href="https://colab.research.google.com/github/ereason/neural-network-iis-lab3/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import keras as kr
import seaborn as sb

tf.test.gpu_device_name()

from google.colab import files

#file = files.upload()
X_train = pd.read_csv("xtrain.csv", header=None)
Y_train = pd.read_csv("ytrain.csv", header=None)
X_test = pd.read_csv("xtest.csv", header=None)
Y_test = pd.read_csv("ytest.csv", header=None)

from keras.models import Sequential
from keras.layers import Dense

classifier = Sequential() # Инициализация НС
classifier.add(Dense(units = 16, activation = 'relu', input_dim = 30))
classifier.add(Dense(units = 8, activation = 'relu'))
classifier.add(Dense(units = 6, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

classifier.compile(optimizer = 'rmsprop', loss = 'binary_crossentropy')

classifier.fit(X_train, Y_train, batch_size = 1, epochs = 25)

Y_pred = classifier.predict(X_test) # подаём на вход обученной НС тестовый набор данных
Y_pred = [ 1 if y>=0.5 else 0 for y in Y_pred ]

total = 0
correct = 0
wrong = 0
for i in range(len(Y_pred)):
  total=total+1
  if(Y_test.at[i,0] == Y_pred[i]):
    correct=correct+1
  else:
    wrong=wrong+1

print("Total " + str(total))
print("Correct " + str(correct))
print("Wrong " + str(wrong))
# Out:
# Epoch 1/25
# 455/455 [==============================] - 11s 4ms/step - loss: 0.3643
# Epoch 2/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.1170
# Epoch 3/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0886
# Epoch 4/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0860
# Epoch 5/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0790
# Epoch 6/25
# 455/455 [==============================] - 3s 6ms/step - loss: 0.0777
# Epoch 7/25
# 455/455 [==============================] - 3s 6ms/step - loss: 0.0686
# Epoch 8/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0747
# Epoch 9/25
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0725
# Epoch 10/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0710
# Epoch 11/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0714
# Epoch 12/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0672
# Epoch 13/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0701
# Epoch 14/25
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0685
# Epoch 15/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0716
# Epoch 16/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0645
# Epoch 17/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0647
# Epoch 18/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0677
# Epoch 19/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0638
# Epoch 20/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0587
# Epoch 21/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0645
# Epoch 22/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0585
# Epoch 23/25
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0645
# Epoch 24/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0581
# Epoch 25/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0646
# 4/4 [==============================] - 0s 3ms/step
# Total 114
# Correct 111
# Wrong 3

# %%
import tensorflow as tf
import pandas as pd
import keras as kr
import seaborn as sb

tf.test.gpu_device_name()

from google.colab import files

#file = files.upload()
X_train = pd.read_csv("xtrain.csv", header=None)
Y_train = pd.read_csv("ytrain.csv", header=None)
X_test = pd.read_csv("xtest.csv", header=None)
Y_test = pd.read_csv("ytest.csv", header=None)

from keras.models import Sequential
from keras.layers import Dense

classifier = Sequential() # Инициализация НС
classifier.add(Dense(units = 32, activation = 'relu', input_dim = 30))
classifier.add(Dense(units = 16, activation = 'relu'))
classifier.add(Dense(units = 8, activation = 'relu'))
classifier.add(Dense(units = 6, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

classifier.compile(optimizer = 'rmsprop', loss = 'binary_crossentropy')

classifier.fit(X_train, Y_train, batch_size = 1, epochs = 25)

Y_pred = classifier.predict(X_test) # подаём на вход обученной НС тестовый набор данных
Y_pred = [ 1 if y>=0.5 else 0 for y in Y_pred ]

total = 0
correct = 0
wrong = 0
for i in range(len(Y_pred)):
  total=total+1
  if(Y_test.at[i,0] == Y_pred[i]):
    correct=correct+1
  else:
    wrong=wrong+1

print("Total " + str(total))
print("Correct " + str(correct))
print("Wrong " + str(wrong))
# Out:
# Epoch 1/25
# 455/455 [==============================] - 2s 3ms/step - loss: 0.2327
# Epoch 2/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0918
# Epoch 3/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0769
# Epoch 4/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0785
# Epoch 5/25
# 455/455 [==============================] - 2s 3ms/step - loss: 0.0731
# Epoch 6/25
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0721
# Epoch 7/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0727
# Epoch 8/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0858
# Epoch 9/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0705
# Epoch 10/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0690
# Epoch 11/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0769
# Epoch 12/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0816
# Epoch 13/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0700
# Epoch 14/25
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0617
# Epoch 15/25
# 455/455 [==============================] - 2s 3ms/step - loss: 0.0689
# Epoch 16/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0615
# Epoch 17/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0680
# Epoch 18/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0683
# Epoch 19/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0644
# Epoch 20/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0615
# Epoch 21/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0514
# Epoch 22/25
# 455/455 [==============================] - 2s 3ms/step - loss: 0.0569
# Epoch 23/25
# 455/455 [==============================] - 2s 4ms/step - loss: 0.0510
# Epoch 24/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0502
# Epoch 25/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.0526
# 4/4 [==============================] - 0s 3ms/step
# Total 114
# Correct 113
# Wrong 1

# %%
import tensorflow as tf
import pandas as pd
import keras as kr
import seaborn as sb

tf.test.gpu_device_name()

from google.colab import files

#file = files.upload()
X_train = pd.read_csv("xtrain.csv", header=None)
Y_train = pd.read_csv("ytrain.csv", header=None)
X_test = pd.read_csv("xtest.csv", header=None)
Y_test = pd.read_csv("ytest.csv", header=None)

from keras.models import Sequential
from keras.layers import Dense

classifier = Sequential() # Инициализация НС
classifier.add(Dense(units = 16, activation = 'relu', input_dim = 30))
classifier.add(Dense(units = 8, activation = 'relu'))
classifier.add(Dense(units = 6, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

classifier.compile(optimizer = 'adadelta', loss = 'binary_crossentropy')

classifier.fit(X_train, Y_train, batch_size = 1, epochs = 25)

Y_pred = classifier.predict(X_test) # подаём на вход обученной НС тестовый набор данных
Y_pred = [ 1 if y>=0.5 else 0 for y in Y_pred ]

total = 0
correct = 0
wrong = 0
for i in range(len(Y_pred)):
  total=total+1
  if(Y_test.at[i,0] == Y_pred[i]):
    correct=correct+1
  else:
    wrong=wrong+1

print("Total " + str(total))
print("Correct " + str(correct))
print("Wrong " + str(wrong))
# Out:
# Epoch 1/25
# 455/455 [==============================] - 3s 3ms/step - loss: 0.7827
# Epoch 2/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7811
# Epoch 3/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7795
# Epoch 4/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7780
# Epoch 5/25
# 455/455 [==============================] - 2s 4ms/step - loss: 0.7764
# Epoch 6/25
# 455/455 [==============================] - 2s 4ms/step - loss: 0.7748
# Epoch 7/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7732
# Epoch 8/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7715
# Epoch 9/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7699
# Epoch 10/25
# 455/455 [==============================] - 2s 3ms/step - loss: 0.7683
# Epoch 11/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7667
# Epoch 12/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7651
# Epoch 13/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7635
# Epoch 14/25
# 455/455 [==============================] - 2s 4ms/step - loss: 0.7619
# Epoch 15/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7604
# Epoch 16/25
# 455/455 [==============================] - 2s 3ms/step - loss: 0.7588
# Epoch 17/25
# 455/455 [==============================] - 2s 4ms/step - loss: 0.7572
# Epoch 18/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7557
# Epoch 19/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7541
# Epoch 20/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7526
# Epoch 21/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7511
# Epoch 22/25
# 455/455 [==============================] - 2s 4ms/step - loss: 0.7495
# Epoch 23/25
# 455/455 [==============================] - 2s 5ms/step - loss: 0.7480
# Epoch 24/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7464
# Epoch 25/25
# 455/455 [==============================] - 1s 3ms/step - loss: 0.7449
# 4/4 [==============================] - 0s 2ms/step
# Total 114
# Correct 33
# Wrong 81

# %%
import tensorflow as tf
import pandas as pd
import keras as kr
import seaborn as sb

tf.test.gpu_device_name()

from google.colab import files

#file = files.upload()
X_train = pd.read_csv("xtrain.csv", header=None)
Y_train = pd.read_csv("ytrain.csv", header=None)
X_test = pd.read_csv("xtest.csv", header=None)
Y_test = pd.read_csv("ytest.csv", header=None)

from keras.models import Sequential
from keras.layers import Dense

classifier = Sequential() # Инициализация НС
classifier.add(Dense(units = 16, activation = 'relu', input_dim = 30))
classifier.add(Dense(units = 8, activation = 'relu'))
classifier.add(Dense(units = 6, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

classifier.compile(optimizer = 'adadelta', loss = 'mean_absolute_error')

classifier.fit(X_train, Y_train, batch_size = 1, epochs = 10)

Y_pred = classifier.predict(X_test) # подаём на вход обученной НС тестовый набор данных
Y_pred = [ 1 if y>=0.5 else 0 for y in Y_pred ]

total = 0
correct = 0
wrong = 0
for i in range(len(Y_pred)):
  total=total+1
  if(Y_test.at[i,0] == Y_pred[i]):
    correct=correct+1
  else:
    wrong=wrong+1

print("Total " + str(total))
print("Correct " + str(correct))
print("Wrong " + str(wrong))
# Out:
# Epoch 1/10
# 455/455 [==============================] - 2s 3ms/step - loss: 0.4854
# Epoch 2/10
# 455/455 [==============================] - 1s 3ms/step - loss: 0.4848
# Epoch 3/10
# 455/455 [==============================] - 2s 4ms/step - loss: 0.4843
# Epoch 4/10
# 455/455 [==============================] - 1s 3ms/step - loss: 0.4837
# Epoch 5/10
# 455/455 [==============================] - 1s 3ms/step - loss: 0.4831
# Epoch 6/10
# 455/455 [==============================] - 1s 3ms/step - loss: 0.4825
# Epoch 7/10
# 455/455 [==============================] - 1s 3ms/step - loss: 0.4819
# Epoch 8/10
# 455/455 [==============================] - 1s 3ms/step - loss: 0.4813
# Epoch 9/10
# 455/455 [==============================] - 1s 3ms/step - loss: 0.4807
# Epoch 10/10
# 455/455 [==============================] - 1s 3ms/step - loss: 0.4801
# 4/4 [==============================] - 0s 3ms/step
# Total 114
# Correct 52
# Wrong 62
